# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine

# %% [markdown]
# ### 读取数据

# %%
import os

# %%
# 数据库地址：数据库放在上一级目录下
db_path = os.path.join(os.path.dirname(os.getcwd()),"data.db")
engine_path = "sqlite:///"+db_path

# %%
# 获取数据函数，根据输入的SQL语句返回 DataFrame 类型数据
def link_sqlite(sql):
    engine = create_engine(engine_path)
    df = pd.read_sql(sql,con=engine)
    return df

# %%
sql = "select * from salesSummary"
df = link_sqlite(sql)

# %% [markdown]
# ### 数据描述

# %%
df.shape
# Out:
# (30, 3)

# %%
df.sample(5)
# Out:
#       商品        淘宝        京东
# 2    商品3  36430286  35423924
# 17  商品18  33776459  31924303
# 8    商品9  11854916  11164280
# 15  商品16  47493063  46536876
# 0    商品1  10126430   9485938

# %%
# 数据描述
df.describe()
# Out:
#                  淘宝            京东
# count  3.000000e+01  3.000000e+01
# mean   2.236863e+07  2.133120e+07
# std    1.416729e+07  1.366177e+07
# min    1.542652e+06  1.459513e+06
# 25%    1.289473e+07  1.202880e+07
# 50%    1.935684e+07  1.846384e+07
# 75%    3.003195e+07  2.890284e+07
# max    5.440054e+07  4.991992e+07

# %%
# 将科学计数法修改为正常显示
np.set_printoptions(suppress=True)
pd.set_option("display.float_format",lambda x:"%.f"%x)
df.describe()
# Out:
#             淘宝       京东
# count       30       30
# mean  22368632 21331203
# std   14167289 13661774
# min    1542652  1459513
# 25%   12894730 12028804
# 50%   19356840 18463844
# 75%   30031946 28902836
# max   54400538 49919921

# %%
# 添加一列总销售额
df["总销售额"] = df["淘宝"]+df["京东"]

# %%
# 淘宝店总销售额
df["淘宝"].sum()
# Out:
# 671058957

# %%
# 京东店总销售额
df["京东"].sum()
# Out:
# 639936097

# %%
# 销售额最高的商品
df[df["总销售额"]==df["总销售额"].max()]
# Out:
#       商品        淘宝        京东       总销售额
# 18  商品19  54400538  49919921  104320459

# %%
# 销售额最低的商品
df[df["总销售额"]==df["总销售额"].min()]
# Out:
#       商品       淘宝       京东     总销售额
# 25  商品26  1542652  1459513  3002165

# %% [markdown]
# ### 柱状图对比

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar

x_names = df["商品"].tolist()
tao_bao = [round(x/10000,2) for x in df["淘宝"].tolist()]
jing_dong = [round(x/10000,2) for x in df["京东"].tolist()]

c = (
    Bar()
    .add_xaxis(x_names)
    .add_yaxis("淘宝", tao_bao)
    .add_yaxis("京东", jing_dong)
    .set_global_opts(
        xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=-15)),
        title_opts=opts.TitleOpts(title="商品销售额分析"),
    )
    .set_series_opts(
        label_opts=opts.LabelOpts(is_show=False),
        markpoint_opts=opts.MarkPointOpts(
            data=[
                opts.MarkPointItem(type_="max", name="最大值"),
                opts.MarkPointItem(type_="min", name="最小值"),
            ]
        ),
        markline_opts=opts.MarkLineOpts(
            data=[
                opts.MarkLineItem(type_="average", name="平均值"),
            ]
        ),
    )
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="0a3a260c163d4180a62bf9d12700a86d" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_0a3a260c163d4180a62bf9d12700a86d = echarts.init(
#                     document.getElementById('0a3a260c163d4180a62bf9d12700a86d'), 'white', {renderer: 'canvas'});
#                 var option_0a3a260c163d4180a62bf9d12700a86d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u6dd8\u5b9d",
#             "legendHoverLink": true,
#             "data": [
#                 1012.64,
#                 690.71,
#                 3643.03,
#                 1833.88,
#                 1283.82,
#                 2214.77,
#                 1390.72,
#                 1942.61,
#                 1185.49,
#                 3962.67,
#                 2796.56,
#                 3024.55,
#                 1898.11,
#                 2300.35,
#                 4844.69,
#                 4749.31,
#                 2939.12,
#                 3377.65,
#                 5440.05,
#                 2392.47,
#                 459.23,
#                 1460.89,
#                 4082.78,
#                 1790.55,
#                 2385.67,
#                 154.27,
#                 1928.76,
#                 1306.42,
#                 291.38,
#                 322.74
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "name": "\u6700\u5927\u503c",
#                         "type": "max"
#                     },
#                     {
#                         "name": "\u6700\u5c0f\u503c",
#                         "type": "min"
#                     }
#                 ]
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "name": "\u5e73\u5747\u503c",
#                         "type": "average"
#                     }
#                 ]
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u4eac\u4e1c",
#             "legendHoverLink": true,
#             "data": [
#                 948.59,
#                 603.16,
#                 3542.39,
#                 1737.33,
#                 1186.8,
#                 2159.86,
#                 1354.56,
#                 1888.79,
#                 1116.43,
#                 3903.42,
#                 2646.12,
#                 2925.5,
#                 1791.32,
#                 2156.43,
#                 4734.58,
#                 4653.69,
#                 2784.65,
#                 3192.43,
#                 4991.99,
#                 2209.91,
#                 407.92,
#                 1423.73,
#                 3958.97,
#                 1684.31,
#                 2211.01,
#                 145.95,
#                 1803.98,
#                 1251.11,
#                 271.29,
#                 307.39
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "name": "\u6700\u5927\u503c",
#                         "type": "max"
#                     },
#                     {
#                         "name": "\u6700\u5c0f\u503c",
#                         "type": "min"
#                     }
#                 ]
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "name": "\u5e73\u5747\u503c",
#                         "type": "average"
#                     }
#                 ]
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6dd8\u5b9d",
#                 "\u4eac\u4e1c"
#             ],
#             "selected": {
#                 "\u6dd8\u5b9d": true,
#                 "\u4eac\u4e1c": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "rotate": -15,
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5546\u54c11",
#                 "\u5546\u54c12",
